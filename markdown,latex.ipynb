# %% [markdown]
# # Язык разметки Markdown

# %% [markdown]
# # Заголовок первого уровня
# ## Заголовок второго уровня
# ### Заголовок третьего уровня

# %% [markdown]
# **жирный текст**
#
# *курсивный текст*

# %%
- или + маркированный список
1. нумерованный список

[текст ссылки](сслыка)

\ перенос на новую строку

# %% [markdown]
# # LaTex (для верстки формул и чего угодно)

# %% [markdown]
# ## Основные команды:

# %% [markdown]
# Для оформления формул всегда окружаем их знаками долларов $ $ (или $$...$$, чтоб центрировать формулу).

# %% [markdown]
# 1. ### Надстрочные и подстрочные индексы:

# %% [markdown]
# $$\textit{A}_{индекс}^{\textit{степень}}$$

# %% [markdown]
# Для введения текста на русском нужна команда \textit{}. В фигурные скобки оборачиваем весь текст на кириллице.

# %% [markdown]
# 2. ### Дроби:

# %% [markdown]
# $$ \frac{\mathbb{E}
# (\hat{\theta}_n - \theta)^2}{\epsilon^2}$$

# %%
Для оформления дробей \frac{числитель}{знаменатель}.

# %% [markdown]
# ## Пример:

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import math
from numpy import array, exp


def p(a,b):
    z = np.polyfit(a, b, 3.5)
    p = np.poly1d(z)
    return(p)

n = [133.6, 523.2, 675.9, 909.7, 1172.6]
eps = [0.199, 0.0074,  0.00123, 0.000882, 0.00284]

for i in range(len(n)):
    n[i] = 1.039*n[i] - 3.587

fig, ax = plt.subplots()
plt.scatter(n, eps, marker='.', color='red', s=170)
plt.plot(n, p(n,eps)(n), color='black')

plt.xlabel(r'$E_{\gamma, эксп}$, кэВ', fontsize=16)
plt.ylabel(r'$E_{\gamma, табл}$, кэВ', fontsize=16)
# plt.legend(edgecolor='white', fontsize = 11, loc='best')
plt.show()

# %%
То есть r'$...$' позволяет оформлять подписи к осям в латех.
